# %% [markdown]
# ### Peak frequencies for each area

# %%
import sys

sys.path.insert(1, "/home/vinicius/storage1/projects/phase_coupling_analysis")

# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import pycircular
import scipy
import seaborn as sns
import xarray as xr
from frites.conn import conn_reshape_undirected
from frites.conn.conn_utils import conn_links
from scipy.signal import find_peaks
from scipy.stats import circmean, circstd, circvar
from sklearn.metrics import euclidean_distances
from tqdm import tqdm
from xarray_einstats.stats import circmean, circstd

from src.signal.surrogates import trial_swap_surrogates
from src.util import _extract_roi, get_dates

# %%
# Define the matrix using ranges where necessary
xy_grid_lucy = [
    [0, 0, 0, 0, 0, 0] + list(range(248, 253)),
    [0, 0, 0, 0, 0] + list(range(242, 248)),
    [0, 0, 0] + list(range(234, 242)),
    [0, 0] + list(range(225, 234)),
    [0, 0] + list(range(216, 225)),
    [0] + list(range(206, 216)),
    list(range(195, 206)),
    list(range(184, 195)),
    list(range(173, 184)),
    list(range(162, 173)),
    list(range(151, 162)),
    list(range(140, 151)),
    list(range(129, 140)),
    list(range(118, 129)),
    list(range(107, 118)),
    list(range(96, 107)),
    list(range(85, 96)),
    list(range(74, 85)),
    [0] + list(range(64, 74)),
    [0, 0] + list(range(55, 64)),
    [0, 0] + list(range(46, 55)),
    [0, 0] + list(range(37, 46)),
    [0, 0, 0] + list(range(29, 37)),
    [0, 0, 0] + list(range(21, 29)),
    [0, 0, 0, 0, 0] + list(range(15, 21)),
    [0, 0, 0, 0, 0] + list(range(9, 15)),
    [0, 0, 0, 0, 0, 0, 0] + list(range(5, 9)),
    [0, 0, 0, 0, 0, 0, 0] + list(range(1, 5)),
]

# Convert to NumPy array and transpose
xy_grid_lucy = np.array(xy_grid_lucy).T

# %% [markdown]
# #### Load data

# %%
dates = get_dates("lucy")

# %%
nsessions = 0
peak_freqs_corrected = []

for date in tqdm(dates):

    _get_data_path = lambda date: os.path.expanduser(
        f"/home/vinicius/funcog/phaseanalysis/Results/lucy/{date}"
    )

    DATA_PATH = _get_data_path(date)

    average_power = xr.load_dataarray(os.path.join(DATA_PATH, "average_power.nc"))
    peak_freqs = xr.load_dataarray(os.path.join(DATA_PATH, "peak_freqs.nc"))

    roi = average_power.roi.values

    roi_gp, roi_idx = roi, np.arange(len(roi)).reshape(-1, 1)

    _, pairs = conn_links(roi_gp)

    ##################################################################### Compute white matters distances #####################################################################

    wmd = pd.read_excel(
        "/home/vinicius/Documents/WhiteMatterDistance.xlsx", index_col=0
    ).fillna(0)

    r, c = wmd.shape

    for i in range(r):
        for j in range(c):
            if isinstance(wmd.values[i, j], str):
                try:
                    wmd.iloc[i, j] = float(wmd.values[i, j].replace(",", "."))
                except:
                    wmd.values[i, j] = 0.

    # White matter distances

    rois_ch_s, rois_ch_t = _extract_roi(pairs, "-")

    _, rois_s = _extract_roi(rois_ch_s, "_")
    _, rois_t = _extract_roi(rois_ch_t, "_")

    wmd_pairs = []
    for s, t in zip(rois_s, rois_t):
        temp = wmd.loc[wmd.index == s, wmd.columns == t].values.squeeze()
        if temp.any():
            wmd_pairs += [temp]
        else:
            wmd_pairs += [np.nan]

    wmd_pairs = xr.DataArray(
        np.hstack(wmd_pairs).squeeze(), dims=("roi"), coords={"roi": pairs}, name="wmd"
    )

    average_power.attrs["xp"] = np.zeros(average_power.sizes["roi"])
    average_power.attrs["yp"] = np.zeros(average_power.sizes["roi"])

    for pos, c in enumerate(average_power.attrs["channels_labels"]):
        x, y = np.where(xy_grid_lucy == c)
        average_power.attrs["xp"][pos] = x[0] * 2.3
        average_power.attrs["yp"][pos] = y[0] * 2.3

    xyz = np.stack(
        (
            average_power.attrs["xp"],
            average_power.attrs["yp"],
            average_power.attrs["z"][average_power.attrs["indch"]] / 1000,
        ),
        axis=1,
    )

    ed = pd.DataFrame(
        euclidean_distances(xyz),
        index=average_power.roi.data,
        columns=average_power.roi.data,
    )

    rois_ch_s, rois_ch_t = _extract_roi(pairs, "-")
    ed_pairs = []

    for s, t in zip(rois_ch_s, rois_ch_t):
        ed_pairs += [ed.loc[ed.index == s, ed.columns == t].values]

    ed_pairs = xr.DataArray(
        np.hstack(ed_pairs).squeeze(), dims=("roi"), coords={"roi": pairs}, name="ed"
    )

    temp = xr.concat((wmd_pairs, ed_pairs), "metrics")

    distances = temp.max("metrics")

    mask = (ed_pairs < wmd_pairs).values

    distances[mask] = temp.isel(roi=mask).mean("metrics")

    distances = conn_reshape_undirected(distances)

    ##################################################################### Correct peak frequenciess #####################################################################

    for i in range(5):

        # Indexes of channels with undetected peaks
        indexes = np.where(peak_freqs[i] == -1)[0]
        if len(indexes) > 0:
            for ind in indexes:
                roi = peak_freqs[i, ind].roi.values
                peak_freq_neighbor = peak_freqs[i].sel(
                    roi=distances.sel(sources=roi).argsort()[::-1].targets[0].values
                )
                j = 1
                while peak_freq_neighbor == -1:
                    peak_freq_neighbor = peak_freqs[i].sel(
                        roi=distances.sel(sources=roi).argsort()[::-1].targets[j].values
                    )
                    j = j + 1
                peak_freqs[i, ind] = peak_freq_neighbor

    peak_freqs_corrected += [peak_freqs]
# Out:
#   0%|                                                                 | 0/62 [00:00<?, ?it/s]Defining links (n_roi=82; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#   2%|▉                                                        | 1/62 [00:04<04:39,  4.58s/it]Defining links (n_roi=47; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#   3%|█▊                                                       | 2/62 [00:07<03:53,  3.89s/it]Defining links (n_roi=57; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#   5%|██▊                                                      | 3/62 [00:11<03:37,  3.68s/it]Defining links (n_roi=68; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#   6%|███▋                                                     | 4/62 [00:15<03:39,  3.79s/it]Defining links (n_roi=93; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#   8%|████▌                                                    | 5/62 [00:20<04:04,  4.29s/it]Defining links (n_roi=78; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  10%|█████▌                                                   | 6/62 [00:24<03:58,  4.26s/it]Defining links (n_roi=47; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  11%|██████▍                                                  | 7/62 [00:27<03:34,  3.90s/it]Defining links (n_roi=75; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  13%|███████▎                                                 | 8/62 [00:31<03:33,  3.96s/it]Defining links (n_roi=73; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  15%|████████▎                                                | 9/62 [00:36<03:31,  3.99s/it]Defining links (n_roi=72; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  16%|█████████                                               | 10/62 [00:40<03:27,  4.00s/it]Defining links (n_roi=56; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  18%|█████████▉                                              | 11/62 [00:43<03:14,  3.81s/it]Defining links (n_roi=67; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  19%|██████████▊                                             | 12/62 [00:47<03:10,  3.82s/it]Defining links (n_roi=63; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  21%|███████████▋                                            | 13/62 [00:50<03:05,  3.78s/it]Defining links (n_roi=44; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  23%|████████████▋                                           | 14/62 [00:54<02:55,  3.66s/it]Defining links (n_roi=61; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  24%|█████████████▌                                          | 15/62 [00:58<03:04,  3.93s/it]Defining links (n_roi=55; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  26%|██████████████▍                                         | 16/62 [01:02<03:02,  3.96s/it]Defining links (n_roi=53; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  27%|███████████████▎                                        | 17/62 [01:07<03:03,  4.07s/it]Defining links (n_roi=67; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  29%|████████████████▎                                       | 18/62 [01:12<03:13,  4.40s/it]Defining links (n_roi=57; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  31%|█████████████████▏                                      | 19/62 [01:16<03:08,  4.37s/it]Defining links (n_roi=64; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  32%|██████████████████                                      | 20/62 [01:21<03:08,  4.50s/it]Defining links (n_roi=58; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  34%|██████████████████▉                                     | 21/62 [01:26<03:07,  4.58s/it]Defining links (n_roi=51; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  35%|███████████████████▊                                    | 22/62 [01:30<02:57,  4.43s/it]Defining links (n_roi=69; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  37%|████████████████████▊                                   | 23/62 [01:35<03:04,  4.73s/it]Defining links (n_roi=71; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  39%|█████████████████████▋                                  | 24/62 [01:41<03:07,  4.94s/it]Defining links (n_roi=74; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  40%|██████████████████████▌                                 | 25/62 [01:46<03:09,  5.13s/it]Defining links (n_roi=55; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  42%|███████████████████████▍                                | 26/62 [01:50<02:50,  4.74s/it]Defining links (n_roi=55; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():
# /home/vinicius/Documents/frites/frites/conn/conn_utils.py:520: FutureWarning: the `pandas.MultiIndex` object(s) passed as 'roi' coordinate(s) or data variable(s) will no longer be implicitly promoted and wrapped into multiple indexed coordinates in the future (i.e., one coordinate for each multi-index level + one dimension coordinate). If you want to keep this behavior, you need to first wrap it explicitly using `mindex_coords = xarray.Coordinates.from_pandas_multiindex(mindex_obj, 'dim')` and pass it as coordinates, e.g., `xarray.Dataset(coords=mindex_coords)`, `dataset.assign_coords(mindex_coords)` or `dataarray.assign_coords(mindex_coords)`.
#   da[axis] = pd.MultiIndex.from_arrays(
#  44%|████████████████████████▍                               | 27/62 [01:55<02:42,  4.66s/it]Defining links (n_roi=49; directed=False; net=False, nb_min_links=None)
#     Sorting roi names
# /home/vinicius/anaconda3/envs/ipp/lib/python3.9/site-packages/openpyxl/worksheet/_read_only.py:79: UserWarning: Unknown extension is not supported and will be removed
#   for idx, row in parser.parse():

# %%
temp.astype(float)

# %%
xr.concat(peak_freqs_corrected, "sessions").mean("sessions").to_netcdf(
    "data/peak_freqs.nc"
)

# %%
wmd

# %%
distances.astype(float)

# %%
i, j = 0, 2

# %%
wmd.values[i, j] = float(wmd.values[i, j].replace(",", "."))

# %%
wmd.iloc[0, 2] = float(wmd.values[i, j].replace(",", "."))

# %%
wmd = pd.read_excel(
    "/home/vinicius/Documents/WhiteMatterDistance.xlsx", index_col=0
).fillna(0.)

# %%
wmd.iloc[0, 2]

# %%
float(wmd.values[0, 2].replace(",", "."))

# %%
i, j
